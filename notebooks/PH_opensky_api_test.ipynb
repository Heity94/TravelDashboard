# %%
#muss man halt einmal runterladen: https://github.com/openskynetwork/opensky-api
#pip install -e /Users/jonaspieper/Documents/GitHub/opensky-api/python
# Out:
# Obtaining file:///Users/jonaspieper/Documents/GitHub/opensky-api/python
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for opensky-api
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from opensky_api import OpenSkyApi

# %%
api = OpenSkyApi()

# %%
#da sind alle infos drin zeitpunkt JETZT, siehe states.time: 
states = api.get_states()

# %%
#das ist die aktuelle Flughöhe:
for s in states.states:
    print(s.baro_altitude)
# Out:
# 11894.82
# None
# 1059.18
# 8976.36
# 10355.58
# 3657.6
# None
# 3688.08
# 9136.38
# 2659.38
# 1234.44
# 5189.22
# 335.28
# 2560.32
# 11277.6
# None
# 1706.88
# 11277.6
# 670.56
# 883.92
# None
# 1158.24
# 7924.8
# 9448.8
# 11582.4
# 11582.4
# 4259.58
# 609.6
# 99.06
# 11887.2
# 175.26
# 10523.22
# 167.64
# 9753.6
# 10043.16
# 8237.22
# 3444.24
# 556.26
# 922.02
# 396.24
# 3985.26
# 10279.38
# 617.22
# 10652.76
# 10668
# 6522.72
# 11582.4
# 1470.66
# 1661.16
# 967.74
# 510.54
# 9745.98
# 11277.6
# 5890.26
# 91.44
# 7254.24
# 754.38
# 11582.4
# 7353.3
# 274.32
# 99.06
# 6469.38
# 3627.12
# 1325.88
# 213.36
# None
# 10066.02
# 5486.4
# 11879.58
# None
# 4267.2
# 10363.2
# 11582.4
# 7688.58
# 10972.8
# 518.16
# 6484.62
# 38.1
# None
# 10972.8
# 3962.4
# 8839.2
# 723.9
# 10972.8
# -22.86
# 10972.8
# 9753.6
# 6606.54
# None
# 1386.84
# 10668
# 6210.3
# None
# 11285.22
# 10972.8
# 11582.4
# 7010.4
# 9250.68
# 7246.62
# 350.52
# 3970.02
# None
# 12496.8
# 419.1
# 9959.34
# 11597.64
# None
# ...

# %%
states.time
# Out:
# 1652442215

# %%
states.states[0].keys
# Out:
# ['icao24',
#  'callsign',
#  'origin_country',
#  'time_position',
#  'last_contact',
#  'longitude',
#  'latitude',
#  'baro_altitude',
#  'on_ground',
#  'velocity',
#  'true_track',
#  'vertical_rate',
#  'sensors',
#  'geo_altitude',
#  'squawk',
#  'spi',
#  'position_source']

# %%
# Thats how you call it 
states.states[0].icao24
# Out:
# '4b1815'

# %%
states.states[0].callsign
# Out:
# 'SWR79W  '
