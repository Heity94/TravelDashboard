# %%
#muss man halt einmal runterladen: https://github.com/openskynetwork/opensky-api
#pip install -e /Users/jonaspieper/Documents/GitHub/opensky-api/python
# Out:
# Obtaining file:///Users/jonaspieper/Documents/GitHub/opensky-api/python
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for opensky-api
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from opensky_api import OpenSkyApi
import pandas as pd
from geopy.geocoders import Nominatim
import requests
import json

# %%
api = OpenSkyApi()

# %%
#da sind alle infos drin zeitpunkt JETZT, siehe states.time: 
states = api.get_states()

# %%
#das ist die aktuelle Flughöhe:
for s in states.states:
    print(s.on_ground)
# Out:
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# True
# False
# False
# False
# True
# False
# True
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# ...

# %%
states4.time
# Out:
# 1652365244

# %%
states1 = api.get_states()

# %%
states2 = api.get_states()

# %%
states3 = api.get_states()

# %%
states4 = api.get_states()

# %%
states1.time
# Out:
# 1652639431

# %%
print(states1.time, states2.time, states3.time, states4.time)
# Out:
# 1652365153 1652365177 1652365214 1652365244

# %%
states1.states[0]
# Out:
# StateVector(dict_values(['4b1814', 'SWR31E  ', 'Switzerland', 1652639430, 1652639431, 0.4371, 51.3762, 5219.7, False, 215.31, 100.88, 8.45, None, 5387.34, '2240', False, 0]))

# %%
altitude1 = []
for s in states1.states:
    altitude1.append(s.baro_altitude)

# %%
altitude2 = []
for s in states1.states:
    altitude2.append(s.baro_altitude)

# %%
altitude3 = []
for s in states1.states:
    altitude3.append(s.baro_altitude)

# %%
altitude4 = []
for s in states1.states:
    altitude4.append(s.baro_altitude)

# %%
altitudes = pd.DataFrame(
    {'altitude1': altitude1,
     'altitude2': altitude2,
     'altitude3': altitude3,
     'altitude4': altitude4,
    })

# %%
altitudes = altitudes.dropna()

# %%
altitudes.sort_values('altitude1')
# Out:
#       altitude1  altitude2  altitude3  altitude4
# 337     -121.92    -121.92    -121.92    -121.92
# 179     -114.30    -114.30    -114.30    -114.30
# 4352    -106.68    -106.68    -106.68    -106.68
# 6993    -106.68    -106.68    -106.68    -106.68
# 4377    -106.68    -106.68    -106.68    -106.68
# ...         ...        ...        ...        ...
# 2826   14325.60   14325.60   14325.60   14325.60
# 584    14325.60   14325.60   14325.60   14325.60
# 5792   18013.68   18013.68   18013.68   18013.68
# 4784   20330.16   20330.16   20330.16   20330.16
# 1743   30876.24   30876.24   30876.24   30876.24
#
# [8433 rows x 4 columns]

# %%
states4 = api.get_states()

# %%
states4.states[100]
# Out:
# StateVector(dict_values(['abaceb', 'ASA1017 ', 'United States', 1652444692, 1652444692, -94.4641, 45.231, 6781.8, False, 203.68, 288.71, 9.43, None, 6934.2, None, False, 0]))

# %%
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
Latitude = "25.594095"
Longitude = "85.137566"
  
location = geolocator.reverse(Latitude+","+Longitude, language=True)
  
# Display
print(location)
Longitude = "85.137566"
  
location = geolocator.reverse(Latitude+","+Longitude)
  
# Display
print(location)
# Out:
# Patna, Patna Rural, Patna District, Bihar, 800001, India
# Patna, Patna Rural, Patna District, Bihar, 800001, India

# %%
Latitude = "50.0944"
Longitude = "8.7377	"
  
location = geolocator.reverse(Latitude+","+Longitude, language="en-GB", addressdetails=False)

# Display
print(location)
# Out:
# 9, Im Teller, Oberrad, Süd, Frankfurt, Hesse, 60599, Germany

# %%
lon_min,lat_min=-125.974,30.038
lon_max,lat_max=-68.748,52.214

# %%
user_name=''
password=''
url_data='https://'+user_name+':'+password+'@opensky-network.org/api/states/all?'#+'lamin='+str(lat_min)+'&lomin='+str(lon_min)+'&lamax='+str(lat_max)+'&lomax='+str(lon_max)
response=requests.get(url_data).json()

# %%
col_name=['icao24','callsign','origin_country','time_position','last_contact','long','lat','baro_altitude','on_ground','velocity',       
'true_track','vertical_rate','sensors','geo_altitude','squawk','spi','position_source']
flight_df=pd.DataFrame(response['states'])
flight_df=flight_df.loc[:,0:16]
flight_df.columns=col_name
flight_df=flight_df.fillna('No Data') #replace NAN with No Data
flight_df.head()
# Out:
#    icao24  callsign origin_country time_position  last_contact      long  \
# 0  4b1814  SWR35Q      Switzerland  1652695769.0    1652695769    8.5505
# 1  4b1816  SWR1742     Switzerland  1652695740.0    1652695760     8.556
# 2  e8027c  LPE2352           Chile  1652695768.0    1652695768   -76.925
# 3  e8027d  LPE2083           Chile  1652695768.0    1652695768  -76.8913
# 4  7c6b2d  JST447        Australia  1652695769.0    1652695769  151.5609
#
#        lat baro_altitude  on_ground velocity true_track vertical_rate  \
# 0  47.4549       No Data       True    12.35     140.62       No Data
# 1   47.452       No Data       True      0.0     334.69       No Data
# 2 -11.8218       5356.86      False   188.63      31.39         12.03
# 3 -12.0946       3307.08      False    176.1      43.82          5.53
# 4 -29.6295       10972.8      False   212.43     218.31           0.0
#
#    sensors geo_altitude   squawk    spi  position_source
# ...

# %%
flight_df
# Out:
#       icao24  callsign origin_country time_position  last_contact      long  \
# 0     4b1814  SWR35Q      Switzerland  1652695769.0    1652695769    8.5505
# 1     4b1816  SWR1742     Switzerland  1652695740.0    1652695760     8.556
# 2     e8027c  LPE2352           Chile  1652695768.0    1652695768   -76.925
# 3     e8027d  LPE2083           Chile  1652695768.0    1652695768  -76.8913
# 4     7c6b2d  JST447        Australia  1652695769.0    1652695769  151.5609
# ...      ...       ...            ...           ...           ...       ...
# 4807  4403f0  EJU38YF         Austria  1652695769.0    1652695769    4.8829
# 4808  a0c7b3  GTI3854   United States  1652695768.0    1652695769  -92.0563
# 4809  398549  DINGO81          France  1652695765.0    1652695765   -0.7003
# 4810  4b1900  EDW11K      Switzerland  1652695767.0    1652695767    8.5491
# 4811  458662  CAT330          Denmark  1652695768.0    1652695769   28.0669
#
# ...

# %%
def filter_rows_by_values(df, col, values):
    return df[~df[col].isin(values)]

# %%
#delete baro altitude = No Data
flight_df = filter_rows_by_values(flight_df, "baro_altitude", ["No Data"])

# %%
#convert baro altitude into float
flight_df['baro_altitude'] = flight_df['baro_altitude'].astype(float)
# Out:
# /var/folders/r8/ml9zphbs05z5wx9ykw9g7r_40000gn/T/ipykernel_7606/1800158256.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flight_df['baro_altitude'] = flight_df['baro_altitude'].astype(float)

# %%
#flights under 1000m --> must be landing or starting
flight_df[flight_df.baro_altitude < 1000]
# Out:
#       icao24  callsign              origin_country time_position  \
# 21    4aa8b0  SEJEP                         Sweden  1652695690.0
# 64    4845e5  PHBEC     Kingdom of the Netherlands  1652695768.0
# 69    39e55c  FJCOV                         France  1652695768.0
# 75    4845c0  HNL25B    Kingdom of the Netherlands  1652695768.0
# 80    3455d8  VOE3268                        Spain  1652695492.0
# ...      ...       ...                         ...           ...
# 4798  398566  AFR43HC                       France  1652695769.0
# 4801  4caa55  EAI52BP                      Ireland  1652695603.0
# 4802  404866  GSEXX                 United Kingdom  1652695630.0
# 4803  398572  AFR58VA                       France  1652695769.0
# 4809  398549  DINGO81                       France  1652695765.0
#
#       last_contact     long      lat  baro_altitude  on_ground velocity  \
# 21      1652695690  14.4849  63.1951         274.32      False     6.02
# ...

# %%
#looking at vertical rate:
flight_df = filter_rows_by_values(flight_df, "vertical_rate", ["No Data"])
flight_df = filter_rows_by_values(flight_df, "lat", ["No Data"])
flight_df = filter_rows_by_values(flight_df, "long", ["No Data"])
flight_df['vertical_rate'] = flight_df['vertical_rate'].astype(float)

# %%
landing = flight_df[(flight_df['vertical_rate'] < 0) & (flight_df['baro_altitude'] < 1000)]
starting = flight_df[(flight_df['vertical_rate'] > 0) & (flight_df['baro_altitude'] < 1000)]

# %%
landing
# Out:
#       icao24  callsign              origin_country time_position  \
# 21    4aa8b0  SEJEP                         Sweden  1652695690.0
# 64    4845e5  PHBEC     Kingdom of the Netherlands  1652695768.0
# 69    39e55c  FJCOV                         France  1652695768.0
# 75    4845c0  HNL25B    Kingdom of the Netherlands  1652695768.0
# 80    3455d8  VOE3268                        Spain  1652695492.0
# ...      ...       ...                         ...           ...
# 4778  a65b64  JIA5023                United States  1652695643.0
# 4801  4caa55  EAI52BP                      Ireland  1652695603.0
# 4802  404866  GSEXX                 United Kingdom  1652695630.0
# 4803  398572  AFR58VA                       France  1652695769.0
# 4809  398549  DINGO81                       France  1652695765.0
#
#       last_contact     long      lat  baro_altitude  on_ground velocity  \
# 21      1652695690  14.4849  63.1951         274.32      False     6.02
# ...

# %%
landing["lat_long"]=landing['lat'].astype("string")+","+landing['long'].astype("string")
# Out:
# /var/folders/r8/ml9zphbs05z5wx9ykw9g7r_40000gn/T/ipykernel_7606/3222059204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   landing["lat_long"]=landing['lat'].astype("string")+","+landing['long'].astype("string")

# %%
landing["address"] = landing.apply(lambda col: geolocator.reverse(col["lat_long"], language="en-GB", addressdetails=False), axis=1)
# Out:
# /var/folders/r8/ml9zphbs05z5wx9ykw9g7r_40000gn/T/ipykernel_7606/2274969546.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   landing["address"] = landing.apply(lambda col: geolocator.reverse(col["lat_long"], language="en-GB", addressdetails=False), axis=1)

# %%
landing =  landing.dropna()

# %%
landing["country"] = landing.apply(lambda col: col["address"][0].split(",")[-1], axis=1)
# Out:
# /var/folders/r8/ml9zphbs05z5wx9ykw9g7r_40000gn/T/ipykernel_7606/3069486712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   landing["country"] = landing.apply(lambda col: col["address"][0].split(",")[-1], axis=1)

# %%
landing
# Out:
#       icao24  callsign              origin_country time_position  \
# 21    4aa8b0  SEJEP                         Sweden  1652695690.0
# 64    4845e5  PHBEC     Kingdom of the Netherlands  1652695768.0
# 69    39e55c  FJCOV                         France  1652695768.0
# 75    4845c0  HNL25B    Kingdom of the Netherlands  1652695768.0
# 80    3455d8  VOE3268                        Spain  1652695492.0
# ...      ...       ...                         ...           ...
# 4778  a65b64  JIA5023                United States  1652695643.0
# 4801  4caa55  EAI52BP                      Ireland  1652695603.0
# 4802  404866  GSEXX                 United Kingdom  1652695630.0
# 4803  398572  AFR58VA                       France  1652695769.0
# 4809  398549  DINGO81                       France  1652695765.0
#
#       last_contact     long      lat  baro_altitude  on_ground velocity  \
# 21      1652695690  14.4849  63.1951         274.32      False     6.02
# ...
